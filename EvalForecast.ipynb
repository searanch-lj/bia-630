# %%
import pandas as pd
#import seaborn as sns
import matplotlib as pyplot

# %% [markdown]
# # evaluate model

# %%
df = pd.read_csv("EvaluateModel.csv")
# Out:
#              Month  Quantity Produced  PredictedValues  predictWithMA3k  \
# 0     January-2021             4392.0              NaN              NaN
# 1    February-2021             4164.0              NaN              NaN
# 2       March-2021             4870.0              NaN              NaN
# 3       April-2021             4849.0      4475.333333      4475.333333
# 4         May-2021             4624.0      4627.666667      4627.666667
# 5        June-2021             4867.0      4781.000000      4781.000000
# 6        July-2021             4395.0      4780.000000      4780.000000
# 7      August-2021             5221.0      4628.666667      4628.666667
# 8   September-2021             5607.0      4827.666667      4827.666667
# 9     October-2021             5998.0      5074.333333      5074.333333
# 10   November-2021             3328.0      5608.666667      5608.666667
# 11   December-2021             4049.0      4977.666667      4977.666667
# ...

# %%
# Plotting
df.plot(x='Month', y=['Quantity Produced', 'PredictedValues'], figsize=(10, 6), marker='o')
#plt.xlabel('Date')
#plt.ylabel('Value')
#plt.title('Actual vs Predicted Values Over Time')
#plt.grid(True)
#plt.show()
# Out:
# <Axes: xlabel='Month'>
